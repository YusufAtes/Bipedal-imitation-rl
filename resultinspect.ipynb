# %%
import os
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt

# %%
ppo_path = "ppo_256_128/PPO_12"
file_path = "demo_results.csv"

df = pd.read_csv(os.path.join(ppo_path, file_path))

print(df.columns)
#print the maximum distance
print("Max distance: ", df['Distance'].max())
#find the index of the maximum distance
max_distance_index = df['Distance'].idxmax()
df_max_distance = df.iloc[max_distance_index]
print("Max distance row: ", df_max_distance)
# Out:
# Index(['Speed', 'Angle', 'Distance', 'Success', 'Reward'], dtype='object')
# Max distance:  4.2955547655803406
# Max distance row:  Speed             1.5
# Angle        0.217426
# Distance     4.295555
# Success         False
# Reward      78.529215
# Name: 544, dtype: object
